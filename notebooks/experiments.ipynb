# %% [markdown]
# # Giperparametr Sinovlari
#
# Bu notebook turli giperparametrlar bilan tajriba o'tkazish uchun ishlatiladi.
#
# - Learning rate
# - Batch size
# - Dropout
# - Epoch soni
# - Augmentatsiya parametrlari

# %%
import sys
sys.path.append('..')

from utils import load_config, set_seed, get_device
from model import CastCNN
from dataset import get_dataloaders

# %%
config = load_config('../config.yaml')
set_seed(config['seed'])
device = get_device()
print(f'Device: {device}')

# %% [markdown]
# ## Tajribalar
#
# Quyida turli sozlamalar bilan sinovlar o'tkazing.
